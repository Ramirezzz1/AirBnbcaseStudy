# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv.zip')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
NG = air_bnb
print(NG['neighbourhood_group'].unique())
#5 neighborhood groups are available
# print(NG['neighbourhood_group'].mode())
NG['neighbourhood_group'].value_counts().idxmax()
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# 'Manhattan'

# %%
# Are private rooms the most popular in manhattan?
# popular = air_bnb['neighbourhood_group'] + air_bnb['room_type']
# print(Rooms['room_type'].value_counts().idxmax()
# air_bnb[air_bnb.host_id >=2000]
pop = air_bnb[(air_bnb.neighbourhood_group == 'Manhattan') & (air_bnb.room_type == 'Private room')]
popular = air_bnb[['neighbourhood_group','room_type']].value_counts().idxmax
# popular.set_index('neighbourhood_group')
# filt = air_bnb['neighbourhood_group']=='Manhattan'
# air_bnb[filt]
# air_bnb.loc[filt, 'room_type']
popular
#Private rooms are not the most popluar in Manhattan Entire home/apt are.
# Out:
# <bound method Series.idxmax of neighbourhood_group  room_type
# Manhattan            Entire home/apt    13199
# Brooklyn             Private room       10132
#                      Entire home/apt     9559
# Manhattan            Private room        7982
# Queens               Private room        3372
#                      Entire home/apt     2096
# Bronx                Private room         652
# Manhattan            Shared room          480
# Brooklyn             Shared room          413
# Bronx                Entire home/apt      379
# Queens               Shared room          198
# Staten Island        Private room         188
#                      Entire home/apt      176
# Bronx                Shared room           60
# Staten Island        Shared room            9
# dtype: int64>

# %%
# Which hosts are the busiest and based on their reviews?
# host=air_bnb[['host_name','number_of_reviews']]
# host.head
host = air_bnb[['host_name','number_of_reviews']]
host[host['number_of_reviews']==host['number_of_reviews'].max()]
# based on the amount of reviews Donna is the busiest.
# Out:
#       host_name  number_of_reviews
# 11759      Dona                629

# %%
#Which neighorhood group has the highest average price?
rich = air_bnb[['neighbourhood_group','price']].value_counts().idxmax
rich
# Out:
# <bound method Series.idxmax of neighbourhood_group  price
# Manhattan            150      1052
#                      100       885
# Brooklyn             100       867
#                      50        832
# Manhattan            200       819
#                               ...
#                      497         1
#                      498         1
#                      519         1
#                      524         1
# Staten Island        5000        1
# Length: 1542, dtype: int64>

# %%
# Which neighbor hood group has the highest total price?
expensive=air_bnb['neighbourhood_group','price']
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#Which top 5 hosts have the highest total price?
top_host=air_bnb[['host_name','price',]]
top_host.sort_values('price',ascending=False).head(5)
# Out:
#       host_name  price
# 9151   Kathrine  10000
# 17692      Erin  10000
# 29238    Jelena  10000
# 40433      Matt   9999
# 12342       Amy   9999

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

# air_bnb[(air_bnb['availability']==0) & (air_bnb['number_of_reviews'>=100])]
air_bnb[air_bnb.number_of_reviews>=100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 11         5441                    Central Manhattan/near Broadway       7989
# ...         ...                                                ...        ...
# 33943  26877259       *Times Square Luxury Apartment Private Room*  172864847
# 35014  27759146             Cozy corner near Empire State Building  209549523
# 36238  28826608                                 “For Heaven Cakes”  217379941
# 37093  29489893   Beautiful furnished private studio with backyard  222098649
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
#
# ...

# %%
# What host has the highest total of prices and where are they located?

# %%
# When did Danielle from Queens last receive a review?
air_bnb['host_name'].value_counts()
names = air_bnb.groupby(['host_name','neighbourhood_group'])
names
# names.get_group(['host_name']==['Danielle'] & ['neighbourhood_group']==['Queens'])
# filtro = names['host_name'] == 'Danielle'
# names.loc[filtro]
air_bnb[(air_bnb['host_name']=='Danielle') & (air_bnb['neighbourhood_group']=='Queens')].sort_values('last_review', ascending=False).head(1)
# Out:
#              id                                               name   host_id  \
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE  26432133
#
#       host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 22469  Danielle              Queens  East Elmhurst   40.7638  -73.87238
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 22469  Private room     48               1                436  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 22469              16.03                               5               337

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %% [markdown]
# 2. How many listings have completely open availability?

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
